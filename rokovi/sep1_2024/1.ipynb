# %%
import numpy as np

# %%
def generate_data(num_samples=300):
    """
    Generate random XOR data with added noise.
    """
    X = np.random.randn(num_samples, 2)
    y = np.logical_xor(X[:, 0] > 0, X[:, 1] > 0)
    noise = np.random.normal(scale=0.01, size=num_samples)
    X = np.concatenate((X, noise.reshape(-1, 1)), axis=1)
    return X, y

# %%
data = generate_data()
data[0]
# Out:
# array([[ 4.30399107e-01,  2.55791617e-01, -1.09750731e-03],
#        [-1.38956984e+00,  8.60285426e-01,  1.99916267e-02],
#        [-6.88518020e-01,  1.03744332e-01,  9.78112795e-04],
#        [ 2.54605405e+00,  1.56282191e-01,  1.95534102e-03],
#        [ 1.58652584e+00, -9.20381759e-01, -2.66558395e-03],
#        [-9.20181807e-01,  4.86665804e-01,  4.28113026e-03],
#        [ 9.42715507e-01, -7.31768886e-01,  1.87861598e-02],
#        [ 3.07858328e+00, -6.43426898e-01,  3.71281443e-03],
#        [ 6.65655193e-01, -8.27493306e-01,  4.39614250e-03],
#        [-9.62840708e-02, -5.98335171e-01,  1.57852023e-03],
#        [ 5.50130386e-01, -3.96252284e-01,  7.11549557e-03],
#        [-2.45506458e+00, -6.19589612e-01, -1.30874202e-02],
#        [-1.16364074e+00,  3.67654345e-01,  1.65846216e-02],
#        [ 3.19790706e-01,  8.42270773e-01, -2.37040316e-03],
#        [ 4.08696714e-01, -3.57600041e+00, -1.90672816e-02],
#        [ 6.38874155e-01,  3.16011462e-01, -1.07684389e-02],
# ...

# %% [markdown]
# Imaju 2 razlicite klase

# %%
from sklearn.model_selection import train_test_split

# %%
X = data[0]
y = data[1]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, stratify=y, random_state=42)
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (210, 3)
# (210,)
# (90, 3)
# (90,)

# %%
t = 0
f = 0
for value in y:
    if value == True:
        t+=1
    else:
        f+=1
print(t)
print(f)
# Out:
# 158
# 142

# %%
from sklearn.svm import SVC

# %%
svc_linear = SVC(kernel='linear')
svc_rbf = SVC(kernel='rbf')

# %%
svc_linear.fit(X_train, y_train)
svc_rbf.fit(X_train, y_train)
# Out:
# SVC()

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=2)

# %%
X_train
# Out:
# array([[ 3.05756778e-01, -2.35719566e-01, -2.58699357e-03],
#        [ 4.69192248e-01,  1.83580937e-01,  5.10452803e-03],
#        [-9.29365777e-02, -6.38427800e-01,  9.29504023e-04],
#        [ 3.10834922e+00, -1.51333055e+00,  5.33896557e-03],
#        [ 3.57760218e-01,  1.08555838e+00,  8.94121703e-04],
#        [-1.25152366e+00,  9.31556299e-01,  1.21581457e-02],
#        [-1.15784415e+00,  1.02735079e+00, -1.16100180e-02],
#        [-1.36598929e+00, -1.88424914e-01,  1.41426215e-02],
#        [-1.15346980e+00,  1.51850599e+00, -2.10121279e-03],
#        [ 7.22981339e-01,  1.54367471e+00, -5.10795575e-03],
#        [-4.17622178e-01,  1.18116472e-01,  8.78507202e-03],
#        [-1.09491337e+00,  5.89644777e-01, -5.28167127e-03],
#        [-8.85821396e-01, -1.23047582e+00, -1.56663115e-02],
#        [ 4.87198010e-01,  1.31699372e+00,  1.71003464e-02],
#        [-2.50573619e-01, -1.09202196e+00, -1.47048920e-03],
#        [ 1.52998617e+00,  8.20645996e-01, -9.86886823e-03],
# ...

# %%
pca = pca.fit(X_train)
X_train = pca.transform(X_train)
X_test = pca.transform(X_test)

# %%
print(pca.noise_variance_)
print(pca.explained_variance_ratio_.sum())
# Out:
# 9.963096470906618e-05
# 0.9999563516038718

# %%
import pandas as pd

# %%
y_test_pred = svc_linear.predict(pd.DataFrame(y_test))
y_test_pred = svc_rbf.predict(pd.DataFrame(y_test))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 y_test_pred = svc_linear.predict(pd.DataFrame(y_test))
#       2 y_test_pred = svc_rbf.predict(pd.DataFrame(y_test))
#
# File ~/Documents/IP1/ip1/lib/python3.12/site-packages/sklearn/svm/_base.py:822, in BaseSVC.predict(self, X)
#     820     y = np.argmax(self.decision_function(X), axis=1)
#     821 else:
# --> 822     y = super().predict(X)
#     823 return self.classes_.take(np.asarray(y, dtype=np.intp))
#
# File ~/Documents/IP1/ip1/lib/python3.12/site-packages/sklearn/svm/_base.py:436, in BaseLibSVM.predict(self, X)
#     420 def predict(self, X):
#     421     """Perform regression on samples in X.
#     422
#     423     For an one-class model, +1 (inlier) or -1 (outlier) is returned.
#    (...)    434         The predicted values.
#     435     """
# ...
